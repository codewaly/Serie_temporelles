# %%
#Import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#chargement des données du fichier  Openhealth_S-Grippal.csv
df = pd.read_csv('Openhealth_S_Grippal.csv', sep =";")
df.head()
# Out:
#       PERIODE IAS_brut IAS_lisse Incidence_Sentinelles
# 0  2009-07-01      1,7       2,2                   2,3
# 1  2009-07-02      3,4       2,1                   2,3
# 2  2009-07-03      2,1       2,1                   2,3
# 3  2009-07-04      1,3         2                   2,3
# 4  2009-07-05     14,2         2                   2,3

# %%
df['Datetime'] = pd.to_datetime(df['PERIODE'])
df = df.set_index('Datetime')
df.reset_index()
df=df.drop(['PERIODE'],axis=1)
df.head()
# Out:
#            IAS_brut IAS_lisse Incidence_Sentinelles
# Datetime
# 2009-07-01      1,7       2,2                   2,3
# 2009-07-02      3,4       2,1                   2,3
# 2009-07-03      2,1       2,1                   2,3
# 2009-07-04      1,3         2                   2,3
# 2009-07-05     14,2         2                   2,3

# %%
df.describe()
# Out:
#        IAS_brut IAS_lisse Incidence_Sentinelles
# count      1752      1752                  1734
# unique      586       482                   118
# top         0,6       0,7                   0,6
# freq         54        59                   126

# %%
idx=df[df['IAS_brut']==0].index
idx
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', name='Datetime', freq=None)

# %%
plt.figure(figsize=(17,5), dpi=150)
plt.plot(df.index, df['IAS_brut'], color='red');
